# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import pydeck as pdk
import seaborn as sns
sns.set()

data = pd.read_csv("housing.csv")

# %%
# 绘制房价直方图
st.subheader("House Price Distribution")
plt.figure(figsize=(8, 6))
#plt.hist(data["median_house_value"], bins=30,  range=(200000, 500001), color='royalblue', edgecolor='black')
# median_house_value=500001有900多个样本
plt.hist(data['median_house_value'], bins=30, range=(200000, 500001),edgecolor='steelblue')
plt.xlabel("Median House Value")
plt.ylabel("Frequency")
st.pyplot(plt)
# Out:
# DeltaGenerator()
